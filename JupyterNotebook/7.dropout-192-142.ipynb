# %% [markdown]
# ## Prototype: NSFW Image Detector (Male Genital Shaped Items)
# ### Machine Learning and Neural Networks (Template 2: Gather your own dataset)

# %% [markdown]
# Image Classification using CNN Keras | Full implementation
# <br>
# Source: https://www.youtube.com/watch?v=J1jhfAw5Uvo

# %% [markdown]
# Prototype main objective: able to classify positive or negative images to accuracy above 50%
#
# - Binary classification task

# %%
#import libraries
import numpy as np
import random
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from sklearn.utils import shuffle
import seaborn as sns

import tensorflow as tf
#import tensorflow_hub as hub
from keras import models
from keras import layers
from keras import optimizers
from keras import losses
from keras import metrics
from keras import regularizers
# Out:
# WARNING:tensorflow:From C:\Users\C\anaconda3\envs\dpp1\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# import datat from CSV, labeled as one or zero
one_data = np.load('../192-144/1_output.npy')
one_label = np.load('../192-144/1_labels.npy')
zero_data = np.load('../192-144/0_output.npy')
zero_label = np.load('../192-144/0_labels.npy')
#check dtype
type(one_data[0][0])
# Out:
# numpy.uint8

# %%
print(one_data.shape)
# Out:
# (112693, 82944)

# %%
#reshape into 192 x 192 pixels
one_data = one_data.reshape(len(one_data), 192, 144, 3)
zero_data = zero_data.reshape(len(zero_data), 192, 144, 3)

# %%
one_data = tf.data.Dataset.from_tensor_slices((one_data, one_label))
zero_data = tf.data.Dataset.from_tensor_slices((zero_data, zero_label))

# %%
one_data
# Out:
# <_TensorSliceDataset element_spec=(TensorSpec(shape=(192, 144, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
def scale(image, label):
    return (tf.cast(image, tf.float32) / 255.0, label)

# %%
one_data = one_data.map(scale, num_parallel_calls = tf.data.AUTOTUNE)
zero_data = zero_data.map(scale, num_parallel_calls = tf.data.AUTOTUNE)

for image, label in one_data:
    pass

for image, label in zero_data:
    pass

# %%
print(len(one_data))
print(len(zero_data))
# Out:
# 112693
# 112707

# %%
one_data = one_data.shuffle(buffer_size=len(one_data), reshuffle_each_iteration=True)
zero_data = zero_data.shuffle(buffer_size=len(zero_data), reshuffle_each_iteration=True)

# %% [markdown]
# #@tf.function
# def loop():
#     for epoch in tf.range(2):
#         for d in one_data:
#             tf.print(d)
#
#
# loop()

# %%
# custom test, train val split

one_DATASET_SIZE = (len(one_data))
zero_DATASET_SIZE = (len(zero_data))

one_train_size = int(0.5 * one_DATASET_SIZE)
one_val_size = int(0.25 * one_DATASET_SIZE)
one_test_size = int(0.25 * one_DATASET_SIZE)

zero_train_size = int(0.5 * zero_DATASET_SIZE)
zero_val_size = int(0.25 * zero_DATASET_SIZE)
zero_test_size = int(0.25 * zero_DATASET_SIZE)

one_train_dataset = one_data.take(one_train_size)
one_test_dataset = one_data.skip(one_train_size)
one_val_dataset = one_test_dataset.skip(one_val_size)
one_test_dataset = one_test_dataset.take(one_test_size)

zero_train_dataset = zero_data.take(zero_train_size)
zero_test_dataset = zero_data.skip(zero_train_size)
zero_val_dataset = zero_test_dataset.skip(zero_val_size)
zero_test_dataset = zero_test_dataset.take(zero_test_size)

# %%
# check len of all 3 sets
print("Train set:", len(one_train_dataset))
print("Test set:", len(one_test_dataset))
print("Valadation set:", len(one_val_dataset))
# Out:
# Train set: 56346
# Test set: 28173
# Valadation set: 28174

# %%
## merge zero and one datasets and shuffle 

train_dataset = one_train_dataset.concatenate(zero_train_dataset)
test_dataset = one_test_dataset.concatenate(zero_test_dataset)
val_dataset = one_val_dataset.concatenate(zero_val_dataset)

#shuffle
train_dataset = train_dataset.shuffle(buffer_size=len(train_dataset))
test_dataset = test_dataset.shuffle(buffer_size=len(test_dataset))
val_dataset = val_dataset.shuffle(buffer_size=len(val_dataset))

# check len of all 3 sets
print("Train set:", len(train_dataset))
print("Test set:", len(test_dataset))
print("Valadation set:", len(val_dataset))
# Out:
# Train set: 112699
# Test set: 56349
# Valadation set: 56352

# %%
val_dataset
# Out:
# <_ShuffleDataset element_spec=(TensorSpec(shape=(192, 144, 3), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
# batch the sets, default for tf.dataset is 32
batched_train_dataset = train_dataset.batch(96)
batched_test_dataset = test_dataset.batch(96)
batched_val_dataset = val_dataset.batch(96)

# %%
batched_val_dataset
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 192, 144, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %%
# check for un used var clogging memory / memory leak

from __future__ import print_function  # for Python2
import sys

local_vars = list(locals().items())
for var, obj in local_vars:
    # print var over 1gb for removal
    if (sys.getsizeof(obj) / 10000000) >= 1:
        print(var, sys.getsizeof(obj) / 10000000 )

# %% [markdown]
# # building model

# %%
# define function that can run sequential models back to back

def build_model(dropout_units):
    model = Sequential()
    model.add(Conv2D(32, (3,3), strides=2, activation = 'relu', input_shape = (192, 144, 3)))
    model.add(MaxPooling2D((2,2))) 
    model.add(Dropout(dropout_units))
    model.add(Conv2D(96, (3,3), activation = 'relu'))
    model.add(MaxPooling2D((2,2), strides=2))
    model.add(Conv2D(32, (3,3), activation = 'relu'))
    model.add(MaxPooling2D((2,2), strides=2))
    model.add(Dropout(dropout_units))
    
    model.add(Flatten())
    model.add(Dense(64, activation = 'relu'))
    model.add(Dropout(dropout_units))
    model.add(Dense(64, activation = 'relu'))
    model.add(Dense(64, activation = 'relu'))
    model.add(Dropout(dropout_units))
    model.add(Dense(1, activation = 'sigmoid'))
    #optimizers 
    model.compile(loss = 'binary_crossentropy', optimizer = "Adam", metrics = ['accuracy'])
    return model    
#model.summary()

# custom progress bar

# %%
histories = {}

#can input number of hidden units for each layer. Here we will test an increasing large number of hidden units
for i in [0, 0.05, 0.1, 0.2, 0.3, 0.4]:
    callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

    model = build_model(i)
    model_name = str(64) + '-' + str(64) + '-'+ str(64) + '-'+ str(1) + '-' + str(i) 
    print('Training', model_name)
    history = model.fit(batched_train_dataset,
                        epochs= 10,
                        validation_data=batched_val_dataset,
                        verbose = 1,
                        callbacks=[callback]
                       )
    histories[model_name] = history
    results = model.evaluate(batched_test_dataset)
    model.summary()
    model.reset_states() 

#model.reset_states()
# Out:
# WARNING:tensorflow:From C:\Users\C\anaconda3\envs\dpp1\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\C\anaconda3\envs\dpp1\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\C\anaconda3\envs\dpp1\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Training 64-64-64-1-0
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\C\anaconda3\envs\dpp1\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\C\anaconda3\envs\dpp1\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1174/1174 [==============================] - 434s 294ms/step - loss: 0.2922 - accuracy: 0.8775 - val_loss: 0.2420 - val_accuracy: 0.9066
# Epoch 2/10
# 1174/1174 [==============================] - 447s 226ms/step - loss: 0.2271 - accuracy: 0.9087 - val_loss: 0.1918 - val_accuracy: 0.9249
# Epoch 3/10
# 1174/1174 [==============================] - 344s 205ms/step - loss: 0.1936 - accuracy: 0.9233 - val_loss: 0.1693 - val_accuracy: 0.9336
# Epoch 4/10
# 1174/1174 [==============================] - 317s 196ms/step - loss: 0.1716 - accuracy: 0.9336 - val_loss: 0.1649 - val_accuracy: 0.9369
# Epoch 5/10
# 1174/1174 [==============================] - 297s 183ms/step - loss: 0.1582 - accuracy: 0.9382 - val_loss: 0.1386 - val_accuracy: 0.9469
# Epoch 6/10
# 1174/1174 [==============================] - 273s 168ms/step - loss: 0.1480 - accuracy: 0.9426 - val_loss: 0.1316 - val_accuracy: 0.9489
# Epoch 7/10
# 1174/1174 [==============================] - 246s 158ms/step - loss: 0.1407 - accuracy: 0.9453 - val_loss: 0.1307 - val_accuracy: 0.9500
# Epoch 8/10
# 1174/1174 [==============================] - 240s 151ms/step - loss: 0.1310 - accuracy: 0.9497 - val_loss: 0.1464 - val_accuracy: 0.9429
# Epoch 9/10
# 1174/1174 [==============================] - 221s 143ms/step - loss: 0.1227 - accuracy: 0.9533 - val_loss: 0.1120 - val_accuracy: 0.9577
# Epoch 10/10
# 1174/1174 [==============================] - 268s 185ms/step - loss: 0.1182 - accuracy: 0.9551 - val_loss: 0.1053 - val_accuracy: 0.9599
# 587/587 [==============================] - 47s 26ms/step - loss: 0.1049 - accuracy: 0.9605
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 95, 71, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 47, 35, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 47, 35, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 45, 33, 96)        27744
#
#  max_pooling2d_1 (MaxPoolin  (None, 22, 16, 96)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 20, 14, 32)        27680
#
#  max_pooling2d_2 (MaxPoolin  (None, 10, 7, 32)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 10, 7, 32)         0
#
#  flatten (Flatten)           (None, 2240)              0
#
#  dense (Dense)               (None, 64)                143424
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 208129 (813.00 KB)
# Trainable params: 208129 (813.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training 64-64-64-1-0.05
# Epoch 1/10
# 1174/1174 [==============================] - 232s 148ms/step - loss: 0.3072 - accuracy: 0.8705 - val_loss: 0.2683 - val_accuracy: 0.8954
# Epoch 2/10
# 1174/1174 [==============================] - 228s 148ms/step - loss: 0.2392 - accuracy: 0.9036 - val_loss: 0.2237 - val_accuracy: 0.9095
# Epoch 3/10
# 1174/1174 [==============================] - 230s 148ms/step - loss: 0.2046 - accuracy: 0.9187 - val_loss: 0.1793 - val_accuracy: 0.9306
# Epoch 4/10
# 1174/1174 [==============================] - 222s 147ms/step - loss: 0.1835 - accuracy: 0.9274 - val_loss: 0.1678 - val_accuracy: 0.9338
# Epoch 5/10
# 1174/1174 [==============================] - 235s 151ms/step - loss: 0.1701 - accuracy: 0.9334 - val_loss: 0.1421 - val_accuracy: 0.9446
# Epoch 6/10
# 1174/1174 [==============================] - 230s 149ms/step - loss: 0.1599 - accuracy: 0.9377 - val_loss: 0.1395 - val_accuracy: 0.9481
# Epoch 7/10
# 1174/1174 [==============================] - 226s 146ms/step - loss: 0.1490 - accuracy: 0.9419 - val_loss: 0.1379 - val_accuracy: 0.9459
# Epoch 8/10
# 1174/1174 [==============================] - 218s 144ms/step - loss: 0.1412 - accuracy: 0.9456 - val_loss: 0.1255 - val_accuracy: 0.9533
# Epoch 9/10
# 1174/1174 [==============================] - 211s 143ms/step - loss: 0.1340 - accuracy: 0.9486 - val_loss: 0.1145 - val_accuracy: 0.9560
# Epoch 10/10
# 1174/1174 [==============================] - 220s 144ms/step - loss: 0.1284 - accuracy: 0.9514 - val_loss: 0.1179 - val_accuracy: 0.9555
# 587/587 [==============================] - 45s 26ms/step - loss: 0.1213 - accuracy: 0.9549
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 95, 71, 32)        896
#
#  max_pooling2d_3 (MaxPoolin  (None, 47, 35, 32)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 47, 35, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 45, 33, 96)        27744
#
#  max_pooling2d_4 (MaxPoolin  (None, 22, 16, 96)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 20, 14, 32)        27680
#
#  max_pooling2d_5 (MaxPoolin  (None, 10, 7, 32)         0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 10, 7, 32)         0
#
#  flatten_1 (Flatten)         (None, 2240)              0
#
#  dense_4 (Dense)             (None, 64)                143424
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 208129 (813.00 KB)
# Trainable params: 208129 (813.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training 64-64-64-1-0.1
# Epoch 1/10
# 1174/1174 [==============================] - 219s 143ms/step - loss: 0.3022 - accuracy: 0.8715 - val_loss: 0.2489 - val_accuracy: 0.8996
# Epoch 2/10
# 1174/1174 [==============================] - 210s 141ms/step - loss: 0.2378 - accuracy: 0.9054 - val_loss: 0.2192 - val_accuracy: 0.9136
# Epoch 3/10
# 1174/1174 [==============================] - 202s 140ms/step - loss: 0.2163 - accuracy: 0.9144 - val_loss: 0.2104 - val_accuracy: 0.9172
# Epoch 4/10
# 1174/1174 [==============================] - 204s 142ms/step - loss: 0.1952 - accuracy: 0.9238 - val_loss: 0.1708 - val_accuracy: 0.9335
# Epoch 5/10
# 1174/1174 [==============================] - 215s 149ms/step - loss: 0.1796 - accuracy: 0.9301 - val_loss: 0.1558 - val_accuracy: 0.9387
# Epoch 6/10
# 1174/1174 [==============================] - 204s 144ms/step - loss: 0.1669 - accuracy: 0.9344 - val_loss: 0.1462 - val_accuracy: 0.9440
# Epoch 7/10
# 1174/1174 [==============================] - 215s 144ms/step - loss: 0.1596 - accuracy: 0.9383 - val_loss: 0.1499 - val_accuracy: 0.9412
# Epoch 8/10
# 1174/1174 [==============================] - 208s 143ms/step - loss: 0.1509 - accuracy: 0.9423 - val_loss: 0.1322 - val_accuracy: 0.9500
# Epoch 9/10
# 1174/1174 [==============================] - 200s 140ms/step - loss: 0.1458 - accuracy: 0.9441 - val_loss: 0.1344 - val_accuracy: 0.9473
# Epoch 10/10
# 1174/1174 [==============================] - 211s 142ms/step - loss: 0.1409 - accuracy: 0.9461 - val_loss: 0.1271 - val_accuracy: 0.9519
# 587/587 [==============================] - 41s 24ms/step - loss: 0.1290 - accuracy: 0.9508
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 95, 71, 32)        896
#
#  max_pooling2d_6 (MaxPoolin  (None, 47, 35, 32)        0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 47, 35, 32)        0
#
#  conv2d_7 (Conv2D)           (None, 45, 33, 96)        27744
#
#  max_pooling2d_7 (MaxPoolin  (None, 22, 16, 96)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 20, 14, 32)        27680
#
#  max_pooling2d_8 (MaxPoolin  (None, 10, 7, 32)         0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 10, 7, 32)         0
#
#  flatten_2 (Flatten)         (None, 2240)              0
#
#  dense_8 (Dense)             (None, 64)                143424
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 208129 (813.00 KB)
# Trainable params: 208129 (813.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training 64-64-64-1-0.2
# Epoch 1/10
# 1174/1174 [==============================] - 223s 148ms/step - loss: 0.3119 - accuracy: 0.8696 - val_loss: 0.2451 - val_accuracy: 0.9004
# Epoch 2/10
# 1174/1174 [==============================] - 204s 138ms/step - loss: 0.2478 - accuracy: 0.9019 - val_loss: 0.2134 - val_accuracy: 0.9157
# Epoch 3/10
# 1174/1174 [==============================] - 209s 137ms/step - loss: 0.2190 - accuracy: 0.9126 - val_loss: 0.2209 - val_accuracy: 0.9138
# Epoch 4/10
# 1174/1174 [==============================] - 207s 139ms/step - loss: 0.2035 - accuracy: 0.9212 - val_loss: 0.1749 - val_accuracy: 0.9319
# Epoch 5/10
# 1174/1174 [==============================] - 203s 137ms/step - loss: 0.1901 - accuracy: 0.9266 - val_loss: 0.1672 - val_accuracy: 0.9366
# Epoch 6/10
# 1174/1174 [==============================] - 212s 143ms/step - loss: 0.1817 - accuracy: 0.9305 - val_loss: 0.1710 - val_accuracy: 0.9322
# Epoch 7/10
# 1174/1174 [==============================] - 209s 142ms/step - loss: 0.1755 - accuracy: 0.9327 - val_loss: 0.1654 - val_accuracy: 0.9351
# Epoch 8/10
# 1174/1174 [==============================] - 201s 143ms/step - loss: 0.1658 - accuracy: 0.9373 - val_loss: 0.1427 - val_accuracy: 0.9467
# Epoch 9/10
# 1174/1174 [==============================] - 202s 140ms/step - loss: 0.1597 - accuracy: 0.9392 - val_loss: 0.1443 - val_accuracy: 0.9440
# Epoch 10/10
# 1174/1174 [==============================] - 209s 144ms/step - loss: 0.1553 - accuracy: 0.9415 - val_loss: 0.1483 - val_accuracy: 0.9416
# 587/587 [==============================] - 46s 26ms/step - loss: 0.1449 - accuracy: 0.9433
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 95, 71, 32)        896
#
#  max_pooling2d_9 (MaxPoolin  (None, 47, 35, 32)        0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 47, 35, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 45, 33, 96)        27744
#
#  max_pooling2d_10 (MaxPooli  (None, 22, 16, 96)        0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 20, 14, 32)        27680
#
#  max_pooling2d_11 (MaxPooli  (None, 10, 7, 32)         0
#  ng2D)
#
#  dropout_13 (Dropout)        (None, 10, 7, 32)         0
#
#  flatten_3 (Flatten)         (None, 2240)              0
#
#  dense_12 (Dense)            (None, 64)                143424
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  dense_14 (Dense)            (None, 64)                4160
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_15 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 208129 (813.00 KB)
# Trainable params: 208129 (813.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training 64-64-64-1-0.3
# Epoch 1/10
# 1174/1174 [==============================] - 222s 146ms/step - loss: 0.3173 - accuracy: 0.8670 - val_loss: 0.2475 - val_accuracy: 0.9002
# Epoch 2/10
# 1174/1174 [==============================] - 204s 138ms/step - loss: 0.2550 - accuracy: 0.8976 - val_loss: 0.2223 - val_accuracy: 0.9114
# Epoch 3/10
# 1174/1174 [==============================] - 205s 137ms/step - loss: 0.2294 - accuracy: 0.9094 - val_loss: 0.2123 - val_accuracy: 0.9163
# Epoch 4/10
# 1174/1174 [==============================] - 200s 137ms/step - loss: 0.2093 - accuracy: 0.9171 - val_loss: 0.1911 - val_accuracy: 0.9243
# Epoch 5/10
# 1174/1174 [==============================] - 211s 141ms/step - loss: 0.1938 - accuracy: 0.9255 - val_loss: 0.1861 - val_accuracy: 0.9251
# Epoch 6/10
# 1174/1174 [==============================] - 203s 141ms/step - loss: 0.1894 - accuracy: 0.9264 - val_loss: 0.1758 - val_accuracy: 0.9305
# Epoch 7/10
# 1174/1174 [==============================] - 211s 140ms/step - loss: 0.1798 - accuracy: 0.9305 - val_loss: 0.1871 - val_accuracy: 0.9213
# Epoch 8/10
# 1174/1174 [==============================] - 206s 140ms/step - loss: 0.1738 - accuracy: 0.9338 - val_loss: 0.1657 - val_accuracy: 0.9358
# Epoch 9/10
# 1174/1174 [==============================] - 205s 143ms/step - loss: 0.1684 - accuracy: 0.9349 - val_loss: 0.1454 - val_accuracy: 0.9427
# Epoch 10/10
# 1174/1174 [==============================] - 201s 138ms/step - loss: 0.1627 - accuracy: 0.9378 - val_loss: 0.1408 - val_accuracy: 0.9456
# 587/587 [==============================] - 49s 24ms/step - loss: 0.1395 - accuracy: 0.9450
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 95, 71, 32)        896
#
#  max_pooling2d_12 (MaxPooli  (None, 47, 35, 32)        0
#  ng2D)
#
#  dropout_16 (Dropout)        (None, 47, 35, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 45, 33, 96)        27744
#
#  max_pooling2d_13 (MaxPooli  (None, 22, 16, 96)        0
#  ng2D)
#
#  conv2d_14 (Conv2D)          (None, 20, 14, 32)        27680
#
#  max_pooling2d_14 (MaxPooli  (None, 10, 7, 32)         0
#  ng2D)
#
#  dropout_17 (Dropout)        (None, 10, 7, 32)         0
#
#  flatten_4 (Flatten)         (None, 2240)              0
#
#  dense_16 (Dense)            (None, 64)                143424
#
#  dropout_18 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 64)                4160
#
#  dense_18 (Dense)            (None, 64)                4160
#
#  dropout_19 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 208129 (813.00 KB)
# Trainable params: 208129 (813.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training 64-64-64-1-0.4
# Epoch 1/10
# 1174/1174 [==============================] - 224s 149ms/step - loss: 0.3117 - accuracy: 0.8707 - val_loss: 0.2503 - val_accuracy: 0.9032
# Epoch 2/10
# 1174/1174 [==============================] - 229s 159ms/step - loss: 0.2567 - accuracy: 0.8991 - val_loss: 0.2278 - val_accuracy: 0.9116
# Epoch 3/10
# 1174/1174 [==============================] - 208s 140ms/step - loss: 0.2352 - accuracy: 0.9081 - val_loss: 0.2161 - val_accuracy: 0.9140
# Epoch 4/10
# 1174/1174 [==============================] - 201s 137ms/step - loss: 0.2248 - accuracy: 0.9134 - val_loss: 0.1957 - val_accuracy: 0.9255
# Epoch 5/10
# 1174/1174 [==============================] - 207s 139ms/step - loss: 0.2129 - accuracy: 0.9177 - val_loss: 0.1852 - val_accuracy: 0.9268
# Epoch 6/10
# 1174/1174 [==============================] - 208s 140ms/step - loss: 0.2039 - accuracy: 0.9215 - val_loss: 0.1815 - val_accuracy: 0.9322
# Epoch 7/10
# 1174/1174 [==============================] - 211s 142ms/step - loss: 0.1945 - accuracy: 0.9256 - val_loss: 0.1745 - val_accuracy: 0.9297
# Epoch 8/10
# 1174/1174 [==============================] - 206s 140ms/step - loss: 0.1875 - accuracy: 0.9288 - val_loss: 0.1605 - val_accuracy: 0.9398
# Epoch 9/10
# 1174/1174 [==============================] - 210s 140ms/step - loss: 0.1793 - accuracy: 0.9311 - val_loss: 0.1785 - val_accuracy: 0.9321
# Epoch 10/10
# 1174/1174 [==============================] - 206s 137ms/step - loss: 0.1757 - accuracy: 0.9337 - val_loss: 0.1725 - val_accuracy: 0.9353
# 587/587 [==============================] - 40s 27ms/step - loss: 0.1718 - accuracy: 0.9357
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 95, 71, 32)        896
#
#  max_pooling2d_15 (MaxPooli  (None, 47, 35, 32)        0
#  ng2D)
#
#  dropout_20 (Dropout)        (None, 47, 35, 32)        0
#
#  conv2d_16 (Conv2D)          (None, 45, 33, 96)        27744
#
#  max_pooling2d_16 (MaxPooli  (None, 22, 16, 96)        0
#  ng2D)
#
#  conv2d_17 (Conv2D)          (None, 20, 14, 32)        27680
#
#  max_pooling2d_17 (MaxPooli  (None, 10, 7, 32)         0
#  ng2D)
#
#  dropout_21 (Dropout)        (None, 10, 7, 32)         0
#
#  flatten_5 (Flatten)         (None, 2240)              0
#
#  dense_20 (Dense)            (None, 64)                143424
#
#  dropout_22 (Dropout)        (None, 64)                0
#
#  dense_21 (Dense)            (None, 64)                4160
#
#  dense_22 (Dense)            (None, 64)                4160
#
#  dropout_23 (Dropout)        (None, 64)                0
#
#  dense_23 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 208129 (813.00 KB)
# Trainable params: 208129 (813.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
histories[model_name] = history

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# plot training and validation loss helper functions for future use
acc = history_dict['accuracy']
#define training accuracy 
def plot_acc_comparison(acc_a, label_a, acc_b, label_b,acc_c, label_c, acc_d, label_d, acc_e, label_e, acc_f, label_f, y_label):
    epochs = range(1, len(acc) + 1)
    plt.plot(epochs, acc_a, label=label_a)
    plt.plot(epochs, acc_b, label=label_b)    
    plt.plot(epochs, acc_c, label=label_c) 
    plt.plot(epochs, acc_d, label=label_d) 
    plt.plot(epochs, acc_e, label=label_e) 
    plt.plot(epochs, acc_f, label=label_f) 
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel(y_label)
    plt.legend()
    plt.show()

#define validation accuracy 
def plot_val_acc_comparison(val_acc_a, label_a,val_acc_b, label_b, val_acc_c, label_c, val_acc_d, label_d, val_acc_e, label_e, val_acc_f, label_f, y_label):
    epochs = range(1, len(acc) + 1)
    plt.plot(epochs, val_acc_a, label=label_a)
    plt.plot(epochs, val_acc_b, label=label_b)    
    plt.plot(epochs, val_acc_c, label=label_c) 
    plt.plot(epochs, val_acc_d, label=label_d) 
    plt.plot(epochs, val_acc_e, label=label_e) 
    plt.plot(epochs, val_acc_f, label=label_f) 
    plt.title('Validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel(y_label)
    plt.legend()
    
#define validation loss     
def plot_loss_comparison(loss_a, label_a, loss_b, label_b, loss_c, label_c, loss_d, label_d, loss_e, label_e, loss_f, label_f, y_label):
    epochs = range(1, len(acc) + 1)
    plt.plot(epochs, loss_a, label=label_a)
    plt.plot(epochs, loss_b, label=label_b)    
    plt.plot(epochs, loss_c, label=label_c)
    plt.plot(epochs, loss_d, label=label_d)
    plt.plot(epochs, loss_e, label=label_e)
    plt.plot(epochs, loss_f, label=label_f)
    plt.title('Validation loss')
    plt.xlabel('Epochs')
    plt.ylabel(y_label)
    plt.legend()
    plt.show()
    
#define training loss
def plot_training_loss_comparison(tloss_a, label_a, tloss_b, label_b, tloss_c, label_c, tloss_d, label_d, tloss_e, label_e, tloss_f, label_f, y_label):
    epochs = range(1, len(acc) + 1)
    plt.plot(epochs, tloss_a, label=label_a)
    plt.plot(epochs, tloss_b, label=label_b)    
    plt.plot(epochs, tloss_c, label=label_c) 
    plt.plot(epochs, tloss_d, label=label_d) 
    plt.plot(epochs, tloss_e, label=label_e) 
    plt.plot(epochs, tloss_f, label=label_f) 
    plt.title('Training loss')
    plt.xlabel('Epochs')
    plt.ylabel(y_label)
    plt.legend()
    plt.show()

# %%
#plot for network a
def plot_net_a(acc , label_a, val_acc , label_b, tloss, label_c, loss, label_d, y_label):    
    epochs = range(1, len(acc) + 1)         
    plt.plot(epochs, acc, 'b', label=label_a)
    plt.plot(epochs, val_acc, 'g', label=label_b)    
    plt.plot(epochs, tloss, 'y', label=label_c) 
    plt.plot(epochs, loss, 'm', label=label_d) 
    plt.title('Network A: ' + net_a)
    plt.xlabel('Epochs')
    plt.ylabel(y_label)
    plt.legend()
    plt.grid()
    plt.show()
#plot for network b 
def plot_net_b(acc , label_a, val_acc , label_b, tloss, label_c, loss, label_d, y_label):    
    epochs = range(1, len(acc) + 1)         
    plt.plot(epochs, acc, 'b', label=label_a)
    plt.plot(epochs, val_acc, 'g', label=label_b)    
    plt.plot(epochs, tloss, 'y', label=label_c) 
    plt.plot(epochs, loss, 'm', label=label_d) 
    plt.title('Network B: ' + net_b)
    plt.xlabel('Epochs')
    plt.ylabel(y_label)
    plt.legend()
    plt.grid()
    plt.show()    
#plot for network c 
def plot_net_c(acc , label_a, val_acc , label_b, tloss, label_c, loss, label_d, y_label):    
    epochs = range(1, len(acc) + 1)         
    plt.plot(epochs, acc, 'b', label=label_a)
    plt.plot(epochs, val_acc, 'g', label=label_b)    
    plt.plot(epochs, tloss, 'y', label=label_c) 
    plt.plot(epochs, loss, 'm', label=label_d) 
    plt.title('Network C: ' + net_c)
    plt.xlabel('Epochs')
    plt.ylabel(y_label)
    plt.legend()
    plt.grid()
    plt.show()
#plot for network d 
def plot_net_d(acc , label_a, val_acc , label_b, tloss, label_c, loss, label_d, y_label):    
    epochs = range(1, len(acc) + 1)         
    plt.plot(epochs, acc, 'b', label=label_a)
    plt.plot(epochs, val_acc, 'g', label=label_b)    
    plt.plot(epochs, tloss, 'y', label=label_c) 
    plt.plot(epochs, loss, 'm', label=label_d) 
    plt.title('Network D: ' + net_d)
    plt.xlabel('Epochs')
    plt.ylabel(y_label)
    plt.legend()
    plt.grid()
    plt.show()
#plot for network e
def plot_net_e(acc , label_a, val_acc , label_b, tloss, label_c, loss, label_d, y_label):    
    epochs = range(1, len(acc) + 1)         
    plt.plot(epochs, acc, 'b', label=label_a)
    plt.plot(epochs, val_acc, 'g', label=label_b)    
    plt.plot(epochs, tloss, 'y', label=label_c) 
    plt.plot(epochs, loss, 'm', label=label_d) 
    plt.title('Network E: ' + net_e)
    plt.xlabel('Epochs')
    plt.ylabel(y_label)
    plt.legend()
    plt.grid()
    plt.show()  
    
def plot_net_f(acc , label_a, val_acc , label_b, tloss, label_c, loss, label_d, y_label):    
    epochs = range(1, len(acc) + 1)         
    plt.plot(epochs, acc, 'b', label=label_a)
    plt.plot(epochs, val_acc, 'g', label=label_b)    
    plt.plot(epochs, tloss, 'y', label=label_c) 
    plt.plot(epochs, loss, 'm', label=label_d) 
    plt.title('Network E: ' + net_f)
    plt.xlabel('Epochs')
    plt.ylabel(y_label)
    plt.legend()
    plt.grid()
    plt.show()

# %%
#declare networks according to "histories[model_name]"

net_a, net_b, net_c, net_d, net_e, net_f = '64-64-64-1-Adamax', '64-64-64-1-Adagrad', '64-64-64-1-Adadelta', '64-64-64-1-Adam', '64-64-64-1-RMSProp', '64-64-64-1-SGD'
#plotting accuracy
plot_acc_comparison(acc_a=histories[net_a].history['accuracy'], label_a=net_a,
                     acc_b=histories[net_b].history['accuracy'], label_b=net_b,
                     acc_c=histories[net_c].history['accuracy'], label_c=net_c,
                    acc_d=histories[net_d].history['accuracy'], label_d=net_d,
                    acc_e=histories[net_e].history['accuracy'], label_e=net_e, 
                    acc_f=histories[net_f].history['accuracy'], label_f=net_f, 
                    y_label='Accuracy')
#plotting validation accuracy
plot_val_acc_comparison(val_acc_a=histories[net_a].history['val_accuracy'], label_a=net_a,
                     val_acc_b=histories[net_b].history['val_accuracy'], label_b=net_b,
                     val_acc_c=histories[net_c].history['val_accuracy'], label_c=net_c,
                        val_acc_d=histories[net_d].history['val_accuracy'], label_d=net_d,
                        val_acc_e=histories[net_e].history['val_accuracy'], label_e=net_e, 
                        val_acc_f=histories[net_f].history['val_accuracy'], label_f=net_f, 
                        y_label='Accuracy')

# %%
# plotting loss and validation loss
plot_loss_comparison(loss_a=histories[net_a].history['val_loss'], label_a=net_a,
                     loss_b=histories[net_b].history['val_loss'], label_b=net_b,
                     loss_c=histories[net_c].history['val_loss'], label_c=net_c,
                     loss_d=histories[net_d].history['val_loss'], label_d=net_d,
                     loss_e=histories[net_e].history['val_loss'], label_e=net_e,
                     loss_f=histories[net_f].history['val_loss'], label_f=net_f,
                        y_label='Validation Loss')

plot_training_loss_comparison(tloss_a=histories[net_a].history['loss'], label_a=net_a,
                     tloss_b=histories[net_b].history['loss'], label_b=net_b,
                     tloss_c=histories[net_c].history['loss'], label_c=net_c,
                    tloss_d=histories[net_d].history['loss'], label_d=net_d,
                    tloss_e=histories[net_e].history['loss'], label_e=net_e,
                    tloss_f=histories[net_f].history['loss'], label_f=net_f,
                        y_label='Training Loss')

# %%
# selecting network a, b, c, d, e
plot_net_a(acc=histories[net_a].history['accuracy'], label_a="Accuracy",
           val_acc=histories[net_b].history['val_accuracy'], label_b="Validation accuracy",
            tloss=histories[net_b].history['loss'], label_c="Training loss",
            loss=histories[net_b].history['val_loss'], label_d="Validation loss", y_label='Accuracy / loss')

plot_net_b(acc=histories[net_b].history['accuracy'], label_a="Accuracy",
           val_acc=histories[net_b].history['val_accuracy'], label_b="Validation accuracy",
            tloss=histories[net_b].history['loss'], label_c="Training loss",
            loss=histories[net_b].history['val_loss'], label_d="Validation loss", y_label='Accuracy / loss')

plot_net_c(acc=histories[net_c].history['accuracy'], label_a="Accuracy",
            val_acc=histories[net_c].history['val_accuracy'], label_b="Validation accuracy",
            tloss=histories[net_c].history['loss'], label_c="Training loss",
            loss=histories[net_c].history['val_loss'], label_d="Validation loss", y_label='Accuracy / loss')

plot_net_d(acc=histories[net_d].history['accuracy'], label_a="Accuracy",
            val_acc=histories[net_d].history['val_accuracy'], label_b="Validation accuracy",
            tloss=histories[net_d].history['loss'], label_c="Training loss",
            loss=histories[net_d].history['val_loss'], label_d="Validation loss", y_label='Accuracy / loss')

plot_net_e(acc=histories[net_e].history['accuracy'], label_a="Accuracy",
            val_acc=histories[net_e].history['val_accuracy'], label_b="Validation accuracy",
            tloss=histories[net_e].history['loss'], label_c="Training loss",
            loss=histories[net_e].history['val_loss'], label_d="Validation loss", y_label='Accuracy / loss')

plot_net_f(acc=histories[net_f].history['accuracy'], label_a="Accuracy",
            val_acc=histories[net_f].history['val_accuracy'], label_b="Validation accuracy",
            tloss=histories[net_f].history['loss'], label_c="Training loss",
            loss=histories[net_f].history['val_loss'], label_d="Validation loss", y_label='Accuracy / loss')
